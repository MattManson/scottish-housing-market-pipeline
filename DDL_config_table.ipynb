-- %%
USE CATALOG scottish_housing_ws;

CREATE TABLE IF NOT EXISTS config.cpih_components(
    code STRING,
    name STRING
);

INSERT INTO config.cpih_components VALUES
    ('CP00', 'cpih_all_items'),
    ('CP01', 'food_non_alcoholic'),
    ('CP04', 'housing_energy'),
    ('CP07', 'transport');

-- %%
SELECT * FROM config.cpih_components;
